# %%
import pandas as pd

# %%
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## Column Syntax 1

# %%
# to access the single column
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# # syntax 2

# %%
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
#pitfall with the column having space
df_exams['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %% [markdown]
# ### working on 2 or more columns at once

# %%
# we can access the columns by the 1 syntax

# %%
df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
# we can perform operations on it in the same way

# %% [markdown]
# ## adding a column to a DF

# %%
import numpy as np

# %%
np.random.randint(1,100, size=1000)
# Out:
# array([47,  4, 19, 77, 32, 13, 32, 26, 90, 77, 43, 61, 21, 11, 45, 19, 20,
#        78, 44, 87, 21, 58, 61, 45,  3,  2, 31, 43, 94, 84, 35, 65, 82, 63,
#        15, 45, 93, 64, 29, 77, 44, 78, 63,  3, 62, 51, 71, 94, 36, 47, 24,
#         8, 28, 62, 82, 44, 24, 12, 56, 23, 59, 10, 29, 32, 58, 21, 88, 27,
#        69, 79, 49, 94, 24,  8, 11, 45, 77, 11, 31, 19, 39, 19, 95, 29, 23,
#        26, 80, 29,  5, 60, 86, 91, 98, 60, 30, 15, 99,  3, 37, 98, 22, 47,
#        31, 65, 31, 44, 53, 11, 99, 94, 36,  2, 43, 13, 77,  3, 57, 25, 59,
#        66, 32, 53,  9, 97, 96, 10, 29, 55, 75, 70, 28, 39, 36, 59, 70,  6,
#        13, 79, 75, 16, 28, 41, 30, 88, 72, 84, 60, 36, 15, 54, 35, 36, 19,
#        14, 33, 51,  5, 87,  9, 43, 65, 20, 61, 81, 80, 45, 88, 86, 13, 43,
#        30, 73, 92, 72, 99, 47,  9, 29,  8, 49, 33, 43, 89, 84, 85, 57, 12,
#         6, 15, 80, 35, 94, 94, 38, 33,  9, 70,  3, 55, 16, 52, 58, 39, 70,
#        98, 89, 19, 12, 10, 17, 44, 47, 50, 17, 11, 34, 76, 79, 42, 98, 43,
#        83, 81, 47, 73, 99, 37, 98, 56, 25, 89, 93, 47,  5, 91, 25, 58, 46,
#        85, 88, 21, 16, 96,  9, 27, 31, 39, 90, 42,  8, 61, 37, 22, 44, 14,
#        69,  5, 36, 31, 14, 36, 89, 83, 50, 18, 35, 99, 12, 40, 86, 26, 46,
#        68, 43, 14, 24,  7, 47, 91, 41, 23, 98, 81, 99, 93, 27, 31, 62,  3,
#        41,  5, 97, 21, 36, 78, 55,  1,  7,  3, 45, 36, 15, 79,  2,  9, 27,
#        51, 35, 82, 46, 91, 11, 26, 90, 56, 48, 97, 51, 65, 51, 20,  8, 63,
#        10, 86, 79, 83, 61, 81, 58, 69, 52, 64, 82, 11, 84, 40, 80, 63, 70,
#        82, 40, 26, 94, 22, 22, 94, 33, 49, 10, 36, 16, 96, 80, 85, 54, 38,
#        94,  9, 55, 34, 96,  4, 52, 70, 15, 45, 36, 63, 39,  4, 51, 72, 39,
#        25, 69, 28, 31, 71, 84, 55, 99, 33, 55, 15, 69, 96, 54, 63, 27, 98,
#        38, 50, 87, 36, 93, 14, 90, 76, 61, 92, 99, 77, 90, 73, 73, 83, 51,
#        95, 50, 23, 92, 81, 90, 56, 45, 78, 88, 35, 97, 16, 39, 80, 22, 79,
#         2, 49, 71, 96, 63, 68, 70, 86, 96, 49, 77, 97, 26, 85, 50, 43, 82,
#        93,  3, 30, 56, 46, 55, 88, 40, 11, 33, 25, 88, 16, 41, 27, 77, 76,
#        46, 51, 69,  3, 93, 73, 77, 63, 85,  6, 51, 95, 42, 42, 87, 79,  2,
#        81, 78,  3,  5, 65, 87, 84, 66, 32, 76, 27, 66, 68, 25, 47, 62, 83,
#        51, 70, 29, 50, 95, 23, 43, 40, 90, 52, 58, 78, 83,  2],
#       dtype=int32)

# %%
len(np.random.randint(1,100, size=1000))
# Out:
# 1000

# %%
int_language_score = np.random.randint(1,100, size=1000)

# %%
df_exams['language score'] = int_language_score

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 6
# 1                91
# 2                93
# 3                19
# 4                75
# ..              ...
# 995              51
# 996              84
# 997              52
# 998              72
# 999              63
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## using Assign and insert method

# %%
import pandas as pd

# %%
Score1 = np.random.randint(1,100, size= 1000)
Score2 = np.random.randint(1,100, size= 1000)

# %%
series1 = pd.Series(Score1, index = np.arange(0,1000))
series2 = pd.Series(Score2, index = np.arange(0,1000))

# %%
series2
# Out:
# 0      28
# 1      36
# 2      57
# 3      31
# 4      67
#        ..
# 995    61
# 996    69
# 997    13
# 998    24
# 999    34
# Length: 1000, dtype: int32

# %%
df_exams = df_exams.assign(Score1 = series1, Score2 = series2)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  Score1  Score2
# 0                 6      32      28
# 1                91      99      36
# 2                93      53      57
# 3                19      90      31
# 4                75      61      67
# ..              ...     ...     ...
# 995              51      69      61
# 996              84      72      69
# 997              52      41      13
# 998              72      37      24
# 999              63      11      34
#
# [1000 rows x 11 columns]

# %% [markdown]
# ## insert()

# %%
df_exams.insert(1, "test", series1)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    32        group B           bachelor's degree      standard
# 1    female    99        group C                some college      standard
# 2    female    53        group B             master's degree      standard
# 3      male    90        group A          associate's degree  free/reduced
# 4      male    61        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    69        group E             master's degree      standard
# 996    male    72        group C                 high school  free/reduced
# 997  female    41        group C                 high school  free/reduced
# 998  female    37        group D                some college      standard
# 999  female    11        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  Score1  Score2
# 0                 6      32      28
# 1                91      99      36
# 2                93      53      57
# 3                19      90      31
# 4                75      61      67
# ..              ...     ...     ...
# 995              51      69      61
# 996              84      72      69
# 997              52      41      13
# 998              72      37      24
# 999              63      11      34
#
# [1000 rows x 12 columns]
