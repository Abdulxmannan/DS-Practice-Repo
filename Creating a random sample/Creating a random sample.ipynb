# %%
import pandas as pd

# %%
df = pd.read_csv('players_20.csv')

df.set_index('short_name', inplace=True)
df = df[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality",	"club"]]
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# Neymar Jr                175         68      Brazil
# J. Oblak                 188         87    Slovenia
# E. Hazard                175         74     Belgium
# ...                      ...        ...         ...
# Shao Shuai               186         79    China PR
# Xiao Mingjie             177         66    China PR
# Zhang Wei                186         75    China PR
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# E. Hazard                            Real Madrid
# ...                                          ...
# Shao Shuai                      Beijing Renhe FC
# Xiao Mingjie                    Shanghai SIPG FC
# Zhang Wei                 Hebei China Fortune FC
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df['nationality'].sample(10, random_state=1)
# Out:
# short_name
# D. Cvetinović            Serbia
# M. Silva                Uruguay
# S. Mandash         Saudi Arabia
# I. Gruev               Bulgaria
# Kangin Lee       Korea Republic
# Marc Cardona              Spain
# R. Nteka                 France
# J. Mikel                Nigeria
# He Chao                China PR
# P. Ruffaut               France
# Name: nationality, dtype: object

# %%
df.sample(frac=0.2)
# Out:
#                                long_name  age         dob  height_cm  \
# short_name
# G. Volpe                   Giacomo Volpe   23  1996-01-16        189
# Éder Militão        Éder Gabriel Militão   21  1998-01-18        186
# A. Perea                    Andrés Perea   18  2000-11-14        185
# T. Koch                      Tobias Koch   18  2001-04-06        180
# Son            Fco. Javier Hidalgo Gómez   25  1994-03-30        178
# ...                                  ...  ...         ...        ...
# D. Churlinov             Darko Churlinov   18  2000-07-11        180
# M. Lis                       Mateusz Lis   22  1997-02-27        192
# K. Engel                Konstantin Engel   30  1988-07-27        179
# A. Al Jebreen       Abdulaziz Al Jebreen   29  1990-04-19        179
# M. Modolo                   Marco Modolo   30  1989-03-23        186
#
#                weight_kg    nationality               club
# short_name
# G. Volpe              80          Italy       US Cremonese
# Éder Militão          78         Brazil        Real Madrid
# A. Perea              76       Colombia  Atlético Nacional
# T. Koch               74        Austria      SK Sturm Graz
# Son                   73          Spain    SD Ponferradina
# ...                  ...            ...                ...
# D. Churlinov          71  FYR Macedonia         1. FC Köln
# M. Lis                83         Poland       Wisła Kraków
# K. Engel              79     Kazakhstan      VfL Osnabrück
# A. Al Jebreen         73   Saudi Arabia           Al Nassr
# M. Modolo             82          Italy         Venezia FC
#
# [3656 rows x 7 columns]

# %%
df.sample(frac=2, replace=True)
# Out:
#                                 long_name  age         dob  height_cm  \
# short_name
# R. Kiernan                 Robert Kiernan   28  1991-01-13        186
# R. Özcan                    Ramazan Özcan   35  1984-06-28        184
# M. Caqueret              Maxence Caqueret   19  2000-02-15        174
# S. Patiño                 Santiago Patiño   22  1997-03-10        185
# M. Terrazzino            Marco Terrazzino   28  1991-04-15        177
# ...                                   ...  ...         ...        ...
# J. Glesnes                  Jakob Glesnes   25  1994-03-25        188
# K. Sadiki                  Kosovar Sadiki   20  1998-08-27        193
# J. Aguirre     Leonel Jonás Aguirre Avalo   27  1992-03-05        175
# Zhao Yingjie                          赵英杰   26  1992-08-02        183
# S. Giovinco            Sebastian Giovinco   32  1987-01-26        163
#
#                weight_kg          nationality                 club
# short_name
# R. Kiernan            77  Republic of Ireland      Southend United
# R. Özcan              78              Austria  Bayer 04 Leverkusen
# M. Caqueret           63               France   Olympique Lyonnais
# S. Patiño             82        United States      Orlando City SC
# M. Terrazzino         76              Germany          SC Freiburg
# ...                  ...                  ...                  ...
# J. Glesnes            84               Norway      Strømsgodset IF
# K. Sadiki             70               Canada            Hibernian
# J. Aguirre            69            Argentina      Rosario Central
# Zhao Yingjie          77             China PR      Tianjin TEDA FC
# S. Giovinco           61                Italy             Al Hilal
#
# [36556 rows x 7 columns]
