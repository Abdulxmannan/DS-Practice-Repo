# %%
import pandas as pd

# %%
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import numpy as np

# %%
import random

# %% [markdown]
# # creating a new index

# %%
new_index = np.arange(0,1000)

# %%
random.shuffle(new_index)
new_index
# Out:
# array([200, 185, 513, 375, 877, 396, 972,  39, 472, 861, 106, 727, 364,
#        316, 271, 202, 683, 857,  81,  80, 178, 760,  20, 431, 226, 951,
#        321, 774, 667, 266, 198, 162, 547, 270,  32, 392, 330, 523, 218,
#        473, 803, 916, 732, 555, 490, 755, 351, 660, 550, 662, 314, 329,
#        893, 984, 103, 814, 259, 894, 591,   7, 595, 194, 873, 795, 810,
#        825, 382, 858,  79, 239, 380, 930, 515, 446, 558, 891, 619,  75,
#        964, 124, 856,  66, 958, 539, 651, 401, 639,  88,  38, 100,  64,
#        298, 386, 402, 684, 690, 318, 987, 462, 838, 645, 997, 174, 986,
#        699, 441, 851,  46, 963, 726, 278, 865, 288, 792, 948, 155, 849,
#        836, 312, 110, 994, 631, 721, 105, 416, 428, 943, 562, 601, 245,
#        695, 512, 866, 333, 616, 975, 389, 864, 357, 572, 486, 308, 423,
#        677, 933, 648,  17, 405, 188, 872, 531, 614, 250, 370, 775, 127,
#        689, 467, 693,  23, 791, 793, 609, 224,  76, 205, 167, 846, 139,
# ...

# %%
df_exams['new index'] = new_index
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_exams.set_index('new index' , inplace=True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new index
# 200        female        group B           bachelor's degree      standard
# 185        female        group C                some college      standard
# 513        female        group B             master's degree      standard
# 375          male        group A          associate's degree  free/reduced
# 877          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 817        female        group E             master's degree      standard
# 808          male        group C                 high school  free/reduced
# 448        female        group C                 high school  free/reduced
# 361        female        group D                some college      standard
# 827        female        group D                some college  free/reduced
#
# ...

# %%
df_exams.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new index
# 0          female        group D           bachelor's degree  free/reduced
# 1          female        group C          associate's degree  free/reduced
# 2            male        group C            some high school      standard
# 3            male        group D            some high school      standard
# 4          female        group C           bachelor's degree  free/reduced
# ...           ...            ...                         ...           ...
# 995        female        group D            some high school      standard
# 996          male        group B                some college      standard
# 997          male        group D           bachelor's degree      standard
# 998          male        group B          associate's degree      standard
# 999          male        group D                some college      standard
#
# ...

# %%
df_exams.sort_index(ascending=False, inplace=True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new index
# 999          male        group D                some college      standard
# 998          male        group B          associate's degree      standard
# 997          male        group D           bachelor's degree      standard
# 996          male        group B                some college      standard
# 995        female        group D            some high school      standard
# ...           ...            ...                         ...           ...
# 4          female        group C           bachelor's degree  free/reduced
# 3            male        group D            some high school      standard
# 2            male        group C            some high school      standard
# 1          female        group C          associate's degree  free/reduced
# 0          female        group D           bachelor's degree  free/reduced
#
# ...

# %% [markdown]
# ## rename column

# %%
df_exams.rename(columns={'gender':'Gender'})
# Out:
#            Gender race/ethnicity parental level of education         lunch  \
# new index
# 999          male        group D                some college      standard
# 998          male        group B          associate's degree      standard
# 997          male        group D           bachelor's degree      standard
# 996          male        group B                some college      standard
# 995        female        group D            some high school      standard
# ...           ...            ...                         ...           ...
# 4          female        group C           bachelor's degree  free/reduced
# 3            male        group D            some high school      standard
# 2            male        group C            some high school      standard
# 1          female        group C          associate's degree  free/reduced
# 0          female        group D           bachelor's degree  free/reduced
#
# ...

# %%
df_exams.rename(columns={'math score':'MS',
                         'reading score':'RS',
                         'writing score':'WS'}, inplace=True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new index
# 999          male        group D                some college      standard
# 998          male        group B          associate's degree      standard
# 997          male        group D           bachelor's degree      standard
# 996          male        group B                some college      standard
# 995        female        group D            some high school      standard
# ...           ...            ...                         ...           ...
# 4          female        group C           bachelor's degree  free/reduced
# 3            male        group D            some high school      standard
# 2            male        group C            some high school      standard
# 1          female        group C          associate's degree  free/reduced
# 0          female        group D           bachelor's degree  free/reduced
#
#           test preparation course  MS  RS  WS
# ...

# %% [markdown]
# ## Rename index

# %%
df_exams.rename(index={999:'A',998:'B',997:'C'}, inplace=True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new index
# A            male        group D                some college      standard
# B            male        group B          associate's degree      standard
# C            male        group D           bachelor's degree      standard
# 996          male        group B                some college      standard
# 995        female        group D            some high school      standard
# ...           ...            ...                         ...           ...
# 4          female        group C           bachelor's degree  free/reduced
# 3            male        group D            some high school      standard
# 2            male        group C            some high school      standard
# 1          female        group C          associate's degree  free/reduced
# 0          female        group D           bachelor's degree  free/reduced
#
#           test preparation course  MS  RS  WS
# ...
